# %% [markdown]
# # Exploratory Data Analysis of Walmart Data
#
# First we import our libraries and the data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# %%
features = pd.read_csv("features.csv")
stores = pd.read_csv("stores.csv")
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
features['MarkDown1'] = features['MarkDown1'].fillna(0)
features['MarkDown2'] = features['MarkDown1'].fillna(0)
features['MarkDown3'] = features['MarkDown1'].fillna(0)
features['MarkDown4'] = features['MarkDown1'].fillna(0)
features['MarkDown5'] = features['MarkDown1'].fillna(0)

# display(features[features['MarkDown1'].notnull()].count())
# display(features[features['MarkDown2'].notnull()].count())
# display(features[features['MarkDown3'].notnull()].count())
# display(features[features['MarkDown4'].notnull()].count())
# display(features[features['MarkDown5'].notnull()].count())

# %%
features.sort_values(['Store','Date']).head()
# display(features[features['CPI'].isnull()])
# display(features[features['Unemployment'].isnull()])
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        0.0        0.0
# 1      1  2010-02-12        38.51       2.548        0.0        0.0
# 2      1  2010-02-19        39.93       2.514        0.0        0.0
# 3      1  2010-02-26        46.63       2.561        0.0        0.0
# 4      1  2010-03-05        46.50       2.625        0.0        0.0
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        0.0        0.0        0.0  211.096358         8.106      False
# 1        0.0        0.0        0.0  211.242170         8.106       True
# 2        0.0        0.0        0.0  211.289143         8.106      False
# 3        0.0        0.0        0.0  211.319643         8.106      False
# 4        0.0        0.0        0.0  211.350143         8.106      False

# %%
features['Date'] = pd.to_datetime(features['Date'], format="%Y-%m-%d")
train['Date'] = pd.to_datetime(train['Date'], format="%Y-%m-%d")
test['Date'] = pd.to_datetime(test['Date'], format="%Y-%m-%d")


type(features['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
features['CPI_lag'] = features.groupby(['Store'])['CPI'].shift(1)
features.head()
features['CPI'] = np.where(features['CPI'].isnull(), features['CPI_lag'] , features['CPI'])
features['CPI'] = np.where(features['CPI'].isnull(), 193.589304 , features['CPI'])

features['Unemployment_lag'] = features.groupby(['Store'])['Unemployment'].shift(1)
features.head()
features['Unemployment'] = np.where(features['Unemployment'].isnull(), features['Unemployment_lag'] , features['Unemployment'])
features['Unemployment'] = np.where(features['Unemployment'].isnull(), 8.335 , features['Unemployment'])



display(features)
# Out:
#       Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1 2010-02-05        42.31       2.572       0.00       0.00
# 1         1 2010-02-12        38.51       2.548       0.00       0.00
# 2         1 2010-02-19        39.93       2.514       0.00       0.00
# 3         1 2010-02-26        46.63       2.561       0.00       0.00
# 4         1 2010-03-05        46.50       2.625       0.00       0.00
# 5         1 2010-03-12        57.79       2.667       0.00       0.00
# 6         1 2010-03-19        54.58       2.720       0.00       0.00
# 7         1 2010-03-26        51.45       2.732       0.00       0.00
# 8         1 2010-04-02        62.27       2.719       0.00       0.00
# 9         1 2010-04-09        65.86       2.770       0.00       0.00
# 10        1 2010-04-16        66.32       2.808       0.00       0.00
# 11        1 2010-04-23        64.84       2.795       0.00       0.00
# 12        1 2010-04-30        67.41       2.780       0.00       0.00
# 13        1 2010-05-07        72.55       2.835       0.00       0.00
# 14        1 2010-05-14        74.78       2.854       0.00       0.00
# 15        1 2010-05-21        76.44       2.826       0.00       0.00
# 16        1 2010-05-28        80.44       2.759       0.00       0.00
# 17        1 2010-06-04        80.69       2.705       0.00       0.00
# 18        1 2010-06-11        80.43       2.668       0.00       0.00
# 19        1 2010-06-18        84.11       2.637       0.00       0.00
# 20        1 2010-06-25        84.34       2.653       0.00       0.00
# 21        1 2010-07-02        80.91       2.669       0.00       0.00
# 22        1 2010-07-09        80.48       2.642       0.00       0.00
# 23        1 2010-07-16        83.15       2.623       0.00       0.00
# 24        1 2010-07-23        83.36       2.608       0.00       0.00
# 25        1 2010-07-30        81.84       2.640       0.00       0.00
# 26        1 2010-08-06        87.16       2.627       0.00       0.00
# 27        1 2010-08-13        87.00       2.692       0.00       0.00
# 28        1 2010-08-20        86.65       2.664       0.00       0.00
# 29        1 2010-08-27        85.22       2.619       0.00       0.00
# ...     ...        ...          ...         ...        ...        ...
# 8160     45 2013-01-04        32.87       3.592    1341.33    1341.33
# 8161     45 2013-01-11        38.78       3.611    3877.36    3877.36
# 8162     45 2013-01-18        41.45       3.605   14746.10   14746.10
# 8163     45 2013-01-25        26.49       3.583    3130.28    3130.28
# 8164     45 2013-02-01        34.92       3.615   14508.96   14508.96
# 8165     45 2013-02-08        28.99       3.753   53311.88   53311.88
# 8166     45 2013-02-15        35.87       3.814    9362.02    9362.02
# 8167     45 2013-02-22        31.48       3.859   10781.51   10781.51
# 8168     45 2013-03-01        39.72       3.890    6614.32    6614.32
# 8169     45 2013-03-08        36.13       3.860   16382.54   16382.54
# 8170     45 2013-03-15        42.81       3.834    9867.03    9867.03
# 8171     45 2013-03-22        36.55       3.800   11923.74   11923.74
# 8172     45 2013-03-29        40.68       3.784    5444.00    5444.00
# 8173     45 2013-04-05        43.94       3.763   16427.83   16427.83
# 8174     45 2013-04-12        57.39       3.724    8760.15    8760.15
# 8175     45 2013-04-19        56.27       3.676    1399.81    1399.81
# 8176     45 2013-04-26        50.64       3.615    1260.65    1260.65
# 8177     45 2013-05-03        56.07       3.592    8345.40    8345.40
# 8178     45 2013-05-10        58.86       3.583    4689.18    4689.18
# 8179     45 2013-05-17        60.59       3.614    4515.35    4515.35
# 8180     45 2013-05-24        67.11       3.627    3249.34    3249.34
# 8181     45 2013-05-31        65.88       3.646    6474.49    6474.49
# 8182     45 2013-06-07        70.71       3.633    9977.82    9977.82
# 8183     45 2013-06-14        70.01       3.632    2471.44    2471.44
# 8184     45 2013-06-21        70.13       3.626    4989.34    4989.34
# 8185     45 2013-06-28        76.05       3.639    4842.29    4842.29
# 8186     45 2013-07-05        77.50       3.614    9090.48    9090.48
# 8187     45 2013-07-12        79.37       3.614    3789.94    3789.94
# 8188     45 2013-07-19        82.84       3.737    2961.49    2961.49
# 8189     45 2013-07-26        76.06       3.804     212.02     212.02
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday  \
# 0          0.00       0.00       0.00  211.096358         8.106      False
# 1          0.00       0.00       0.00  211.242170         8.106       True
# 2          0.00       0.00       0.00  211.289143         8.106      False
# 3          0.00       0.00       0.00  211.319643         8.106      False
# 4          0.00       0.00       0.00  211.350143         8.106      False
# 5          0.00       0.00       0.00  211.380643         8.106      False
# 6          0.00       0.00       0.00  211.215635         8.106      False
# 7          0.00       0.00       0.00  211.018042         8.106      False
# 8          0.00       0.00       0.00  210.820450         7.808      False
# 9          0.00       0.00       0.00  210.622857         7.808      False
# 10         0.00       0.00       0.00  210.488700         7.808      False
# 11         0.00       0.00       0.00  210.439123         7.808      False
# 12         0.00       0.00       0.00  210.389546         7.808      False
# 13         0.00       0.00       0.00  210.339968         7.808      False
# 14         0.00       0.00       0.00  210.337426         7.808      False
# 15         0.00       0.00       0.00  210.617093         7.808      False
# 16         0.00       0.00       0.00  210.896761         7.808      False
# 17         0.00       0.00       0.00  211.176428         7.808      False
# 18         0.00       0.00       0.00  211.456095         7.808      False
# 19         0.00       0.00       0.00  211.453772         7.808      False
# 20         0.00       0.00       0.00  211.338653         7.808      False
# 21         0.00       0.00       0.00  211.223533         7.787      False
# 22         0.00       0.00       0.00  211.108414         7.787      False
# 23         0.00       0.00       0.00  211.100385         7.787      False
# 24         0.00       0.00       0.00  211.235144         7.787      False
# 25         0.00       0.00       0.00  211.369903         7.787      False
# 26         0.00       0.00       0.00  211.504662         7.787      False
# 27         0.00       0.00       0.00  211.639421         7.787      False
# 28         0.00       0.00       0.00  211.603363         7.787      False
# 29         0.00       0.00       0.00  211.567306         7.787      False
# ...         ...        ...        ...         ...           ...        ...
# 8160    1341.33    1341.33    1341.33  192.659622         8.625      False
# 8161    3877.36    3877.36    3877.36  192.759980         8.625      False
# 8162   14746.10   14746.10   14746.10  192.809507         8.625      False
# 8163    3130.28    3130.28    3130.28  192.838701         8.625      False
# 8164   14508.96   14508.96   14508.96  192.867895         8.625      False
# 8165   53311.88   53311.88   53311.88  192.897089         8.625       True
# 8166    9362.02    9362.02    9362.02  192.943471         8.625      False
# 8167   10781.51   10781.51   10781.51  193.032822         8.625      False
# 8168    6614.32    6614.32    6614.32  193.122173         8.625      False
# 8169   16382.54   16382.54   16382.54  193.211524         8.625      False
# 8170    9867.03    9867.03    9867.03  193.296277         8.625      False
# 8171   11923.74   11923.74   11923.74  193.369533         8.625      False
# 8172    5444.00    5444.00    5444.00  193.442790         8.625      False
# 8173   16427.83   16427.83   16427.83  193.516047         8.335      False
# 8174    8760.15    8760.15    8760.15  193.589304         8.335      False
# 8175    1399.81    1399.81    1399.81  193.589304         8.335      False
# 8176    1260.65    1260.65    1260.65  193.589304         8.335      False
# 8177    8345.40    8345.40    8345.40  193.589304         8.335      False
# 8178    4689.18    4689.18    4689.18  193.589304         8.335      False
# 8179    4515.35    4515.35    4515.35  193.589304         8.335      False
# 8180    3249.34    3249.34    3249.34  193.589304         8.335      False
# 8181    6474.49    6474.49    6474.49  193.589304         8.335      False
# 8182    9977.82    9977.82    9977.82  193.589304         8.335      False
# 8183    2471.44    2471.44    2471.44  193.589304         8.335      False
# 8184    4989.34    4989.34    4989.34  193.589304         8.335      False
# 8185    4842.29    4842.29    4842.29  193.589304         8.335      False
# 8186    9090.48    9090.48    9090.48  193.589304         8.335      False
# 8187    3789.94    3789.94    3789.94  193.589304         8.335      False
# 8188    2961.49    2961.49    2961.49  193.589304         8.335      False
# 8189     212.02     212.02     212.02  193.589304         8.335      False
#
#          CPI_lag  Unemployment_lag
# 0            NaN               NaN
# 1     211.096358             8.106
# 2     211.242170             8.106
# 3     211.289143             8.106
# 4     211.319643             8.106
# 5     211.350143             8.106
# 6     211.380643             8.106
# 7     211.215635             8.106
# 8     211.018042             8.106
# 9     210.820450             7.808
# 10    210.622857             7.808
# 11    210.488700             7.808
# 12    210.439123             7.808
# 13    210.389546             7.808
# 14    210.339968             7.808
# 15    210.337426             7.808
# 16    210.617093             7.808
# 17    210.896761             7.808
# 18    211.176428             7.808
# 19    211.456095             7.808
# 20    211.453772             7.808
# 21    211.338653             7.808
# 22    211.223533             7.787
# 23    211.108414             7.787
# 24    211.100385             7.787
# 25    211.235144             7.787
# 26    211.369903             7.787
# 27    211.504662             7.787
# 28    211.639421             7.787
# 29    211.603363             7.787
# ...          ...               ...
# 8160  192.559264             8.667
# 8161  192.659622             8.625
# 8162  192.759980             8.625
# 8163  192.809507             8.625
# 8164  192.838701             8.625
# 8165  192.867895             8.625
# 8166  192.897089             8.625
# 8167  192.943471             8.625
# 8168  193.032822             8.625
# 8169  193.122173             8.625
# 8170  193.211524             8.625
# 8171  193.296277             8.625
# 8172  193.369533             8.625
# 8173  193.442790             8.625
# 8174  193.516047             8.335
# 8175  193.589304             8.335
# 8176  193.589304             8.335
# 8177  193.589304             8.335
# 8178  193.589304               NaN
# 8179  193.589304               NaN
# 8180  193.589304               NaN
# 8181  193.589304               NaN
# 8182  193.589304               NaN
# 8183  193.589304               NaN
# 8184  193.589304               NaN
# 8185  193.589304               NaN
# 8186  193.589304               NaN
# 8187  193.589304               NaN
# 8188  193.589304               NaN
# 8189  193.589304               NaN
#
# [8190 rows x 14 columns]

# %%
features2 = features.copy()
features2.drop(['MarkDown1','MarkDown2','MarkDown3','MarkDown4','MarkDown5'],1, inplace = True)
joined = features2.merge(stores, left_on = 'Store', right_on ='Store')
joined.head()
# Out:
#    Store        Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0      1  2010-02-05        42.31       2.572  211.096358         8.106
# 1      1  2010-02-12        38.51       2.548  211.242170         8.106
# 2      1  2010-02-19        39.93       2.514  211.289143         8.106
# 3      1  2010-02-26        46.63       2.561  211.319643         8.106
# 4      1  2010-03-05        46.50       2.625  211.350143         8.106
#
#    IsHoliday Type    Size
# 0      False    A  151315
# 1       True    A  151315
# 2      False    A  151315
# 3      False    A  151315
# 4      False    A  151315

# %% [markdown]
# Which variables appear to be continuous? Categorical? Sparsely Populated? For example, store is a number, but it indicates a categorical
# variable for a specific store. We can update those data types here.

# %%
features['Store'] = pd.Categorical(features.Store)

# %%
sns.distplot(features.Store)

sns.distplot(features.Temperature)

sns.distplot(features.Fuel_Price)

# sns.distplot(features.CPI)
# sns.distplot(features.Unemployment)
# sns.distplot(features.IsHoliday)
# Out:
# C:\Users\mdosani\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\mdosani\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\mdosani\AppData\Local\Continuum\anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %% [markdown]
# We see that our training response variable is the Weekly_Sales variable from the train dataframe. We will need to combine these datasets in a later notebook, but for now we'll continue this exploration on the single datasets.

# %% [markdown]
# ## Next we review various descrptive statistics for the dataframes

# %%
features.describe()
# Out:
#        Temperature   Fuel_Price      MarkDown1      MarkDown2      MarkDown3  \
# count  8190.000000  8190.000000    4032.000000    2921.000000    3613.000000
# mean     59.356198     3.405992    7032.371786    3384.176594    1760.100180
# std      18.678607     0.431337    9262.747448    8793.583016   11276.462208
# min      -7.290000     2.472000   -2781.450000    -265.760000    -179.260000
# 25%      45.902500     3.041000    1577.532500      68.880000       6.600000
# 50%      60.710000     3.513000    4743.580000     364.570000      36.260000
# 75%      73.880000     3.743000    8923.310000    2153.350000     163.150000
# max     101.950000     4.468000  103184.980000  104519.540000  149483.310000
#
#           MarkDown4      MarkDown5          CPI  Unemployment
# count   3464.000000    4050.000000  7605.000000   7605.000000
# mean    3292.935886    4132.216422   172.460809      7.826821
# std     6792.329861   13086.690278    39.738346      1.877259
# min        0.220000    -185.170000   126.064000      3.684000
# 25%      304.687500    1440.827500   132.364839      6.634000
# 50%     1176.425000    2727.135000   182.764003      7.806000
# 75%     3310.007500    4832.555000   213.932412      8.567000
# max    67474.850000  771448.100000   228.976456     14.313000

# %%
stores.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
train.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
#searching for missing values
def missing_values_table(df):
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns
    
    
missing_values_table(features)
# Out:
# Your selected dataframe has 12 columns.
# There are 7 columns that have missing values.
#               Missing Values  % of Total Values
# MarkDown2               5269               64.3
# MarkDown4               4726               57.7
# MarkDown3               4577               55.9
# MarkDown1               4158               50.8
# MarkDown5               4140               50.5
# CPI                      585                7.1
# Unemployment             585                7.1

# %%
missing_values_table(stores)
# Out:
# Your selected dataframe has 3 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %%
missing_values_table(train)
# Out:
# Your selected dataframe has 5 columns.
# There are 0 columns that have missing values.
# Empty DataFrame
# Columns: [Missing Values, % of Total Values]
# Index: []

# %% [markdown]
# It looks like the features dataframe is the only one that has any missing values. We'll continue with distributions and graphs of our dataframes
